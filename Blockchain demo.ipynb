# %% [markdown]
# # Simple Blockchain in Python With Mining
#
# 2 classes:
# - Block
# - Blockchain

# %%
# blockchain.py
import datetime
import hashlib


class Block:
    blockNo = 0
    data = None
    next = None
    hash = None
    nonce = 0
    previous_hash = 0x0
    # if part of network, use time to sync
    timestamp = datetime.datetime.now()
    
    def __init__(self, data):
        self.data = data
        
    def hash(self):
        h = hashlib.sha256()
        h.update(
        str(self.nonce).encode('utf-8') +
        str(self.data).encode('utf-8') +
        str(self.previous_hash).encode('utf-8') +
        str(self.timestamp).encode('utf-8') +
        str(self.blockNo).encode('utf-8')
        )
        return h.hexdigest()
    
    def __str__(self):
        return "Block Hash: " + str(self.hash()) + "\nBlockNo: " + str(self.blockNo) \
               + "\nBlock Data: " + str(self.data) + "\nHashes: " + str(self.nonce) \
               + "\n--------------"
    

class Blockchain:
    diff = 15
    maxNonce = 2 ** 32
    # target range to be excepted
    target = 2 ** (256-diff)
    
    block = Block("Genesis")
    # to make head doesn't reference to same thing as block
    dummy = head = block
    
    def add(self, block):
        block.previous_hash = self.block.hash()
        block.blockNo = self.block.blockNo + 1
        
        self.block.next = block
        self.block = self.block.next
        
    def mine(self, block):
        for n in range(self.maxNonce):
            if int(block.hash(), 16) <= self.target:
                self.add(block)
                print(block)
                break
            else:
                block.nonce += 1 

                
                
blockchain = Blockchain()

for n in range(10):
    blockchain.mine(Block("Block " + str(n+1)))
    
while blockchain.head != None:
    print(blockchain.head)
    blockchain.head = blockchain.head.next
# Out:
# Block Hash: c778c1e42d79c697014afee3c2e46dca22846270c68c0cfa554e652952549e6f
# BlockNo: 1
# Block Data: Block 1
# Hashes: 51363
# --------------
# Block Hash: 102b9cf6afdbbf8b9575bbfa7b4f5a54ea4804300002914f47d704b75da78442
# BlockNo: 2
# Block Data: Block 2
# Hashes: 23288
# --------------
# Block Hash: 6d4dbb1175d0b1eff1b3fae84cbcde79d15a4fcf9d1ee05cf63f75098f0599ec
# BlockNo: 3
# Block Data: Block 3
# Hashes: 34120
# --------------
# Block Hash: 547da4ac4d9913f41c293abfe479fde0ea34d210038450eb6dfa4fa588009482
# BlockNo: 4
# Block Data: Block 4
# Hashes: 10732
# --------------
# Block Hash: 6f740d7ff104852a14747dbf1e28ead1d38fc49446a6a56dfbda0c3a24da4d46
# BlockNo: 5
# Block Data: Block 5
# Hashes: 22081
# --------------
# Block Hash: eb41bf93cb1b479dcad1b7d2900ee6a57ab2726245f3cf4065178a59f7bd8467
# BlockNo: 6
# Block Data: Block 6
# Hashes: 14021
# --------------
# Block Hash: edb9c3bca31fc55422f0922d6f7c0f57dad4cc013885caf56c1570e2f3a5848e
# BlockNo: 7
# Block Data: Block 7
# Hashes: 6446
# --------------
# Block Hash: 4fbc55fb804f8dee8ca61b8f4e2d1e31c141302a52931cc979c3cec61f74da43
# BlockNo: 8
# Block Data: Block 8
# Hashes: 56933
# --------------
# Block Hash: 79609f7ab1f4aa0fd5f4cbdf12f9117cc0394cbf9e24097de1eaedfc5fd81388
# BlockNo: 9
# Block Data: Block 9
# Hashes: 10242
# --------------
# Block Hash: 689a5f02a60a957ce1d85f8898f00aa978603e997923735fd1d05164430642af
# BlockNo: 10
# Block Data: Block 10
# Hashes: 108434
# --------------
# Block Hash: 152a30c5d8ccd72a41bc9c95b2c2af6ab85c1664ddade4263faa2fb9521a8196
# BlockNo: 0
# Block Data: Genesis
# Hashes: 0
# --------------
# Block Hash: c778c1e42d79c697014afee3c2e46dca22846270c68c0cfa554e652952549e6f
# BlockNo: 1
# Block Data: Block 1
# Hashes: 51363
# --------------
# Block Hash: 102b9cf6afdbbf8b9575bbfa7b4f5a54ea4804300002914f47d704b75da78442
# BlockNo: 2
# Block Data: Block 2
# Hashes: 23288
# --------------
# Block Hash: 6d4dbb1175d0b1eff1b3fae84cbcde79d15a4fcf9d1ee05cf63f75098f0599ec
# BlockNo: 3
# Block Data: Block 3
# Hashes: 34120
# --------------
# Block Hash: 547da4ac4d9913f41c293abfe479fde0ea34d210038450eb6dfa4fa588009482
# BlockNo: 4
# Block Data: Block 4
# Hashes: 10732
# --------------
# Block Hash: 6f740d7ff104852a14747dbf1e28ead1d38fc49446a6a56dfbda0c3a24da4d46
# BlockNo: 5
# Block Data: Block 5
# Hashes: 22081
# --------------
# Block Hash: eb41bf93cb1b479dcad1b7d2900ee6a57ab2726245f3cf4065178a59f7bd8467
# BlockNo: 6
# Block Data: Block 6
# Hashes: 14021
# --------------
# Block Hash: edb9c3bca31fc55422f0922d6f7c0f57dad4cc013885caf56c1570e2f3a5848e
# BlockNo: 7
# Block Data: Block 7
# Hashes: 6446
# --------------
# Block Hash: 4fbc55fb804f8dee8ca61b8f4e2d1e31c141302a52931cc979c3cec61f74da43
# BlockNo: 8
# Block Data: Block 8
# Hashes: 56933
# --------------
# Block Hash: 79609f7ab1f4aa0fd5f4cbdf12f9117cc0394cbf9e24097de1eaedfc5fd81388
# BlockNo: 9
# Block Data: Block 9
# Hashes: 10242
# --------------
# Block Hash: 689a5f02a60a957ce1d85f8898f00aa978603e997923735fd1d05164430642af
# BlockNo: 10
# Block Data: Block 10
# Hashes: 108434
# --------------
