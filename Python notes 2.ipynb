# %% [markdown]
# # Background
#
# * Found myself spending a lot of time looking up bash syntax:
#
#     * Why do I need to use `[[ condition ]]` instead of
#       `[ condition ]` again?
#
# > Python is a good scripting language
#
# * So why am I not using it for shell scripting?
#
#     * __Impedance mismatch__
#
# * Decided to investigate current shell scripting/CLI support:
#
# * Found that:
#
#     * Python (3) is awesome for shell scripting!

# %% [markdown]
# # Objectives
#
# Highlight
#
# * *Python 3 features*
#
#     * `f-strings`
#
#     * `pathlib`
#
# * __The *click* library__
#
#     * Makes writing a CLI easy and fun!
#
#     * A replacement for `argparse`, `optparse` and more
#
# * __*Build a CLI* for collecting *cryptocurrency* data for fun and profit!__
#
#     * Learn about
#
#         * *asyncio*
#
#         * *attrs*
#
#         * *streamz*

# %% [markdown]
# # Python 3 features: *f-strings*
#
# * Let's look at bash snippet I use in my deployments:
#
# ```bash
#   LATEST_RELEASE=$(curl -s -X GET http://$(REGISTRY_URL)/v2/$(IMAGE)/tags/list \
#       | jq -r ".tags[]" \
#       | grep -E $(REGEXP_RELEASE) \
#       | sort -V \
#       | tail -n )
# ```
#
# * Gets the job done but not very reusable.
#
# * However one advantage is that the URL is more readable than
#
#   ```python
#   'http://{}/v2/{}/tags/list'.format(REGISTRY_URL, IMAGE)
#   ```
#
# * With *f-strings* this becomes much better:
#
# ```python
# from subprocess import call
# call(f'curl -s -X GET http://{REGISTRY_URL}/v2/{IMAGE}/tags/list')
# ```

# %% [markdown]
# # Python 3 features: *pathlib*
#
# * __`os.path` is dead! Long live *pathlib*!__
#
#   * __`os.path`\'s procedural API had long felt clunky to me.__
#
#   * *pathlib* is awesome!

# %% [markdown]
# ## *pathlib* examples (1): paths

# %%
from pathlib import Path  ##
p = Path('.')
p

str(p)
str(p.absolute())

p = p.absolute()
p.as_posix()

p.as_uri()

p.parent

p.relative_to(p.parent)
# Out:
# PosixPath('notebook')

# %% [markdown]
# ## *pathlib* examples (2): interrogating paths

# %%
q = p / 'newdir'
q

p.exists()  ##

q.exists()

p.is_dir()

p.is_file()
# Out:
# False

# %% [markdown]
# ## *pathlib* examples (3): navigation

# %%
# subdirectories
[x for x in p.iterdir() if x.is_dir()]
# Out:
# [PosixPath('/home/jovyan/work/notebook/.git'),
#  PosixPath('/home/jovyan/work/notebook/Asset'),
#  PosixPath('/home/jovyan/work/notebook/.ipynb_checkpoints')]

# %%
# files
[x for x in p.iterdir() if x.is_file()]
# Out:
# [PosixPath('/home/jovyan/work/notebook/temp_py_api.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Python DP.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Interview Questions.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/python3-ref-3-datamodel.html'),
#  PosixPath('/home/jovyan/work/notebook/Generators.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Python Notes General.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Blockchain demo.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/README.md'),
#  PosixPath('/home/jovyan/work/notebook/REST - Flask.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Flask Tutorial.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/VIM and Python.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Modern Python.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Untitled.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Docker & Kube.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Kubernetes.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Modern Dict.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/.gitignore'),
#  PosixPath('/home/jovyan/work/notebook/python_expert_notebook.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Python Classes.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/LICENSE')]

# %%
# finding files by glob and recursively
list(p.rglob('*'))
# Out:
# [PosixPath('/home/jovyan/work/notebook/temp_py_api.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Python DP.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/.git'),
#  PosixPath('/home/jovyan/work/notebook/Interview Questions.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/python3-ref-3-datamodel.html'),
#  PosixPath('/home/jovyan/work/notebook/Generators.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Python Notes General.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Blockchain demo.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/README.md'),
#  PosixPath('/home/jovyan/work/notebook/REST - Flask.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Flask Tutorial.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/VIM and Python.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Modern Python.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Untitled.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Docker & Kube.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Asset'),
#  PosixPath('/home/jovyan/work/notebook/Kubernetes.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/Modern Dict.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/.gitignore'),
#  PosixPath('/home/jovyan/work/notebook/python_expert_notebook.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/.ipynb_checkpoints'),
#  PosixPath('/home/jovyan/work/notebook/Python Classes.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/LICENSE'),
#  PosixPath('/home/jovyan/work/notebook/.git/ORIG_HEAD'),
#  PosixPath('/home/jovyan/work/notebook/.git/index'),
#  PosixPath('/home/jovyan/work/notebook/.git/refs'),
#  PosixPath('/home/jovyan/work/notebook/.git/COMMIT_EDITMSG'),
#  PosixPath('/home/jovyan/work/notebook/.git/packed-refs'),
#  PosixPath('/home/jovyan/work/notebook/.git/MERGE_MSG~'),
#  PosixPath('/home/jovyan/work/notebook/.git/branches'),
#  PosixPath('/home/jovyan/work/notebook/.git/config'),
#  PosixPath('/home/jovyan/work/notebook/.git/info'),
#  PosixPath('/home/jovyan/work/notebook/.git/description'),
#  PosixPath('/home/jovyan/work/notebook/.git/FETCH_HEAD'),
#  PosixPath('/home/jovyan/work/notebook/.git/HEAD'),
#  PosixPath('/home/jovyan/work/notebook/.git/logs'),
#  PosixPath('/home/jovyan/work/notebook/.git/hooks'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects'),
#  PosixPath('/home/jovyan/work/notebook/.git/refs/tags'),
#  PosixPath('/home/jovyan/work/notebook/.git/refs/remotes'),
#  PosixPath('/home/jovyan/work/notebook/.git/refs/heads'),
#  PosixPath('/home/jovyan/work/notebook/.git/refs/remotes/origin'),
#  PosixPath('/home/jovyan/work/notebook/.git/refs/remotes/origin/HEAD'),
#  PosixPath('/home/jovyan/work/notebook/.git/refs/remotes/origin/master'),
#  PosixPath('/home/jovyan/work/notebook/.git/refs/heads/master'),
#  PosixPath('/home/jovyan/work/notebook/.git/info/exclude'),
#  PosixPath('/home/jovyan/work/notebook/.git/logs/refs'),
#  PosixPath('/home/jovyan/work/notebook/.git/logs/HEAD'),
#  PosixPath('/home/jovyan/work/notebook/.git/logs/refs/remotes'),
#  PosixPath('/home/jovyan/work/notebook/.git/logs/refs/heads'),
#  PosixPath('/home/jovyan/work/notebook/.git/logs/refs/remotes/origin'),
#  PosixPath('/home/jovyan/work/notebook/.git/logs/refs/remotes/origin/HEAD'),
#  PosixPath('/home/jovyan/work/notebook/.git/logs/refs/remotes/origin/master'),
#  PosixPath('/home/jovyan/work/notebook/.git/logs/refs/heads/master'),
#  PosixPath('/home/jovyan/work/notebook/.git/hooks/pre-receive.sample'),
#  PosixPath('/home/jovyan/work/notebook/.git/hooks/pre-applypatch.sample'),
#  PosixPath('/home/jovyan/work/notebook/.git/hooks/applypatch-msg.sample'),
#  PosixPath('/home/jovyan/work/notebook/.git/hooks/pre-rebase.sample'),
#  PosixPath('/home/jovyan/work/notebook/.git/hooks/fsmonitor-watchman.sample'),
#  PosixPath('/home/jovyan/work/notebook/.git/hooks/update.sample'),
#  PosixPath('/home/jovyan/work/notebook/.git/hooks/post-update.sample'),
#  PosixPath('/home/jovyan/work/notebook/.git/hooks/pre-push.sample'),
#  PosixPath('/home/jovyan/work/notebook/.git/hooks/pre-commit.sample'),
#  PosixPath('/home/jovyan/work/notebook/.git/hooks/prepare-commit-msg.sample'),
#  PosixPath('/home/jovyan/work/notebook/.git/hooks/commit-msg.sample'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/c3'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/58'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/ec'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/d0'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/5b'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/2f'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/1f'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/e2'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/2e'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/5a'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/15'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/e6'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/73'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/70'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/c6'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/56'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/28'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects
),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/dd/c91024f4fada8d379a51ba6e5eb9c41d83bda8'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/57/1fd5574e5ecd4db455af9107683910d74f4213'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/57/7030e84d6c371a78b63ba88e297e04c4170d93'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/ff/cca75fe4fb5e92de7ee014b7dcb41013244fcb'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/6b/ce8d7e004b9c3f7ea631ddab3193c6cd6f02b6'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/64/d0c069f46e15ce2d20e28510b8d4af5d40a3aa'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/64/1f75e0ae05afdc3e6a7db9b0a3050dd486a9c1'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/47/27b520880adf67275a1cabe9a653e21617880c'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/b8/2868b885eb25218958c0b3dd033893d96b8f0a'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/8a/e376ae957721a76a8e9c932f24585dd22f09ed'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/0c/e6c2ac78d4042832697fde5d95c1431218eec8'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/07/572dd9c6e8091b363fa776de85f908fdbe9713'),
#  PosixPath('/home/jovyan/work/notebook/.git/objects/07/194a437a8a49d11f9d7a3f404aa599fede36b4'),
#  PosixPath('/home/jovyan/work/notebook/Asset/Microservices - Event Driven.png'),
#  PosixPath('/home/jovyan/work/notebook/Asset/KubeArch_Simple.png'),
#  PosixPath('/home/jovyan/work/notebook/Asset/Microservices - CQRS.png'),
#  PosixPath('/home/jovyan/work/notebook/Asset/KubeService.jpg'),
#  PosixPath('/home/jovyan/work/notebook/Asset/Kube5min.png'),
#  PosixPath('/home/jovyan/work/notebook/Asset/ch04-users-posts[1].png'),
#  PosixPath('/home/jovyan/work/notebook/Asset/data_abstraction.png'),
#  PosixPath('/home/jovyan/work/notebook/Asset/relationships.png'),
#  PosixPath('/home/jovyan/work/notebook/Asset/Microservices - Shared database.png'),
#  PosixPath('/home/jovyan/work/notebook/Asset/Facade_before_after.png'),
#  PosixPath('/home/jovyan/work/notebook/Asset/ch04-users[1].png'),
#  PosixPath('/home/jovyan/work/notebook/.ipynb_checkpoints/Docker & Kube-checkpoint.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/.ipynb_checkpoints/Modern Python-checkpoint.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/.ipynb_checkpoints/Python Notes General-checkpoint.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/.ipynb_checkpoints/temp_py_api-checkpoint.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/.ipynb_checkpoints/Untitled-checkpoint.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/.ipynb_checkpoints/Flask Tutorial-checkpoint.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/.ipynb_checkpoints/Python Classes-checkpoint.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/.ipynb_checkpoints/Generators-checkpoint.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/.ipynb_checkpoints/Python DP-checkpoint.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/.ipynb_checkpoints/Interview Questions-checkpoint.ipynb'),
#  PosixPath('/home/jovyan/work/notebook/.ipynb_checkpoints/python_expert_notebook-checkpoint.ipynb')]

# %% [markdown]
# ## *pathlib* examples (4): object creation
#
# ### directories
# ```python
# q.exists()
#
# q.mkdir()
#
# q.exists()
# ```
#
# ### files
# ```python
# fp = n / 'newfile.txt'
# fp
#
# with fp.open('wt') as f:
#   f.write('The quick brown fox jumped over the lazy dog.')
#
# fp.exists() and fp.is_file()
#
# fp.read_text()
# ```

# %% [markdown]
# ## *pathlib* examples (5): object removal
#
# ### files
# ```python
# fp.unlink()
# fp.exists()
# ```
#
# My only bugbear: __there is no:__
# ```
# fp.rm()
# fp.remove()
# fp.delete()
# ```
#
# ### directories
# ```python
# q.rmdir()
# q.exists()
# ```

# %% [markdown]
# # CLIs
#
# ## Command Line Interfaces
#
# * Reputation as `arcane` and `difficult`
#
#     * 40 years of bad branding
#
# * Rebrand these in line with current trends as *Chatbot Like Interface*!
#
#     * Only half joking: use text to interact with your application!
#
#
#
# * Encourage compositional/functional thinking
#
# * Do one thing well
#
# * Great for automating non-regular tasks

# %% [markdown]
# # Click
#
# ## Command Line Interface Creation Kit
#
# * Lots of features for quickly creating useful interfaces
#
#     * automatic help page generation
#     * parameter validation
#     * arbitrary nesting of commands
#     * supports lazy loading of subcommands at runtime

# %% [markdown]
# ## Basic Example
# ```python
# import click
#
# @click.command()
# @click.option('--count', default=1, help='Number of greetings.')
# @click.option('--name', prompt='Your name', help='The person to greet.')
# def hello(count, name):
#   """Simple program that greets NAME for a total of COUNT times."""
#   for x in range(count):
#       click.echo('Hello {}!'.format(name))
#
# if __name__=='__main__':
#   hello()
#
# ```
#
# * Then run it
#
# ```bash
#   python examples/greet.py
#   python examples/greet.py --name 'PyconZA 2017' --count 3
# ```
#
# ## Setuptools integration
#
# See [http://github.com/snth/numismatic/setup.py](github.com/snth/numismatic.py)
#
# - Then easily install with
# `pip install -e .`

# %% [markdown]
# # Numismatic
#
# ## Motivation
#
# * Make a CLI to collect *cryptocurrency* data
#
# * __Try out__
#
#     * *asyncio*
#
#     * *attrs*
#
#     * *streamz*
#
#     * *websockets*
#
#
# ## *coin* CLI
#
# * Install
# ```bash
# git clone https://github.com/snth/numismatic.git
# cd numismatic
# pip install -e .
# ```
#
# * Run without arguments for help (or with `--help`)
#
# `coin`
#
#
# ## streamz
#
# * Small library by Mathew Rocklin (creator of `dask`) for trying out
#   stream based/reactive event processing in pure Python.
#
# * Self-contained with few dependencies
#
# * Test stream based dataflow before deploying `Kafka`, `Flink`, ...
#
# ```python
# from streamz import Stream
# source = Stream()
#
# source.emit('hello')
# source.emit('world')
#
# printer = source.map(print)
# for event in ['hello', 'world']:
#   source.emit(event)
#
# L = []
# collector = source.map(L.append) j
# for event in ['hello', 'world']:
#   source.emit(event)
# ```
#
#
# ## *attrs*
#
# * I think of it as better *namedtuples*
#
# * Classes without the boilerplate
#
# * Look at `numismatic/events.py`
# ```python
# @attr.s(slots=True)
# class Heartbeat:
#   exchange = attr.ib()
#   symbol = attr.ib()
#   timestamp = attr.ib(default=attr.Factory(time.time))
# ```
#
# * Use it as
#
# ```python
# from numismatic.events import Heartbeat
# Heartbeat('bitfinex', 'BTCUSD')
#
# import attr
# attr.asdict(Heartbeat('bitfinex', 'BTCUSD'))
# ```
#
# ## *asyncio*
#
# * Good tutorials out there.
#
# * I found these helpful:
#
#     * [asyncio — Asynchronous I/O, event loop, and concurrency tools](https://pymotw.com/3/asyncio/)
#
#     * [AsyncIO for the Working Python Developer](https://hackernoon.com/asyncio-for-the-working-python-developer-5c468e6e2e8e)
#
#
# ## *Example*
#
# * Set up our streams
# ```python
# from streamz import Stream
# source = Stream()
# printer = source.map(print)
# L = []
# collector = source.map(L.append)
# ```
#
# * Prepare our connection
# ```python
# from numismatic.exchanges import BitfinexExchange
# bfx = BitfinexExchange(source)
# subscription = bfx.listen('BTCUSD', 'trades')
# ```
#
# * Run the event loop
# ```python
# import asyncio
# loop = asyncio.get_event_loop()
# future = asyncio.wait([subscription], timeout=10)
# loop.run_until_complete(future)
# ```
